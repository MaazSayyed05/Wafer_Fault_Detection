# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/wafer_23012020_041211.csv')
df.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
df.shape
# Out:
# (100, 592)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 592 entries, Unnamed: 0 to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 462.6+ KB

# %%
df.describe()
# Out:
#           Sensor-1     Sensor-2     Sensor-3     Sensor-4   Sensor-5  \
# count    99.000000   100.000000    97.000000    97.000000  97.000000
# mean   3017.301212  2487.180300  2202.168281  1484.362181   1.180367
# std      71.819707    66.954212    30.350606   460.985871   0.349654
# min    2825.670000  2254.990000  2114.666700   978.783200   0.753100
# 25%    2973.040000  2446.595000  2189.966700  1111.543600   0.837300
# 50%    3004.390000  2493.890000  2200.988900  1244.289900   1.156900
# 75%    3070.385000  2527.525000  2213.211100  1963.801600   1.383000
# max    3221.210000  2664.520000  2315.266700  2363.641200   2.207300
#
#        Sensor-6    Sensor-7   Sensor-8    Sensor-9   Sensor-10  ...  \
# count      97.0   97.000000  97.000000  100.000000  100.000000  ...
# mean      100.0   97.449088   0.122195    1.461516    0.000243  ...
# std         0.0    5.553324   0.002006    0.071300    0.010610  ...
# min       100.0   83.423300   0.116000    1.317900   -0.027900  ...
# ...

# %%
# Split dataset into train-test (To avoid data leakage)
from sklearn.model_selection import  train_test_split
wafers_train , wafers_test = train_test_split(df,test_size=0.20,random_state=42)

# %%
wafers_train.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 55  Wafer-856       NaN   2532.45  2191.1333  2197.6570    1.1569     100.0
# 88  Wafer-889   3221.21   2391.20  2189.9667  1046.6212    0.8662     100.0
# 26  Wafer-827   2951.85   2525.00  2189.5777  1320.3197    1.3459     100.0
# 42  Wafer-843   2982.07   2447.06  2199.6334  1242.8420    1.4083     100.0
# 69  Wafer-870   3058.08   2524.60  2192.3778  1110.5453    0.8147     100.0
#
#     Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 55   89.7222    0.1251    1.5762  ...         NaN      0.4936      0.0113
# 88  102.3622    0.1208    1.4756  ...         NaN      0.4940      0.0123
# 26  100.7744    0.1234    1.5590  ...     53.8577      0.5025      0.0178
# 42   99.2178    0.1221    1.4542  ...         NaN      0.4993      0.0151
# 69   99.2922    0.1226    1.4958  ...     24.6547      0.4974      0.0171
#
# ...

# %%
wafers_test.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 83  Wafer-884   2980.66   2437.21  2200.9889  1054.5240    1.3830     100.0
# 53  Wafer-854   3019.98   2515.63  2196.0000  1230.0293    0.7684     100.0
# 70  Wafer-871   3066.38   2473.10  2171.5000  1028.4440    0.7899     100.0
# 45  Wafer-846   3078.60   2441.68  2213.5111  1183.4356    0.7531     100.0
# 44  Wafer-845   3123.02   2488.96  2240.8666  2048.2566    1.1620     100.0
#
#     Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 83  100.1800    0.1201    1.3713  ...         NaN      0.4993      0.0117
# 53   97.5578    0.1219    1.4919  ...    104.3034      0.4968      0.0217
# 70  101.5122    0.1224    1.3623  ...         NaN      0.4998      0.0102
# 45  103.0911    0.1199    1.5250  ...         NaN      0.5009      0.0126
# 44   86.3822    0.1233    1.5540  ...         NaN      0.4948      0.0145
#
# ...

# %%
# Unique values in target feature
wafers_train['Good/Bad'].value_counts()
# Out:
# Good/Bad
# -1    74
#  1     6
# Name: count, dtype: int64

# %% [markdown]
# ## Insight
#  Data is highly imbalanced. Definitely, gonna do `resampling`

# %%
# Analyzing missing values for target feature
wafers_train['Good/Bad'].isna().sum()
# Out:
# 0

# %% [markdown]
# No Missing values or NaN values in dataset

# %%
# Analyzing missing values for dependent features
wafers_train.isna().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      1
# Sensor-2      0
# Sensor-3      2
# Sensor-4      2
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 592, dtype: int64

# %%
wafers_train.isna().sum().sum()
# Out:
# 1822

# %% [markdown]
# Total there are 1822 missing/NaN values in Dependent Features

# %% [markdown]
# # Visualization of Sensors Data

# %%
# Enumerate???
l1 = [1,2,3,4,5]
for i in enumerate(l1):
    print(i)

# It gives pair of(index,value)

for index,val in enumerate(l1):
    print("Index: ",index,"Value: ",val)
# Out:
# (0, 1)
# (1, 2)
# (2, 3)
# (3, 4)
# (4, 5)
# Index:  0 Value:  1
# Index:  1 Value:  2
# Index:  2 Value:  3
# Index:  3 Value:  4
# Index:  4 Value:  5

# %%
# Distribution plot for features
plt.figure(figsize=(15,100))

for i,col in enumerate(wafers_train.columns[1:51]):
    plt.subplot(60,3,i+1)
    sns.distplot(x=wafers_train[col],color="green")
    plt.xlabel(col,weight='bold')
    plt.tight_layout()

# %%
# Select random 50 columns for dist. 
random_50_columns = []
for i in range(50):
    if i  not in random_50_columns:
        random_50_columns.append(np.random.randint(1,591))

# %%
plt.figure(figsize=(15,100))

for i,col in enumerate(wafers_train.columns[random_50_columns]):
    plt.subplot(50,3,i+1)
    sns.distplot(x=wafers_train[col],color="blue")
    plt.xlabel(col,weight='bold')
    plt.tight_layout()

# %%
wafers_train.shape[0]
# Out:
# 80

# %%
wafers_train.isna().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      1
# Sensor-2      0
# Sensor-3      2
# Sensor-4      2
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 592, dtype: int64

# %%
wafers_train.isna().sum().div(wafers_train.shape[0])
# Out:
# Unnamed: 0    0.0000
# Sensor-1      0.0125
# Sensor-2      0.0000
# Sensor-3      0.0250
# Sensor-4      0.0250
#                ...
# Sensor-587    0.0000
# Sensor-588    0.0000
# Sensor-589    0.0000
# Sensor-590    0.0000
# Good/Bad      0.0000
# Length: 592, dtype: float64

# %%
# Get columns to drop
def get_cols_with_zero_std_dev(df: pd.DataFrame):
    """Returns a list of COLUMNS names who are having zero std dev."""
    cols_to_drop = []
    num_cols = [col for col in df.columns if df[col].dtype != 'O']
    for col in num_cols:
        if df[col].std() == 0:
            cols_to_drop.append(col)
    return cols_to_drop



def get_reduntant_cols(df: pd.DataFrame, missing_thresh= 0.7):
    """"
    Returns a list of COLUMNS having missing values more than certain thresh."""

    cols_missing_ratios = df.isna().sum().div(df.shape[0])
    cols_to_drop = list(cols_missing_ratios[cols_missing_ratios > missing_thresh].index)
    return cols_to_drop

# %%
# Drop columns with missing more than 70%
cols_to_drop_1 = get_reduntant_cols(wafers_train,missing_thresh=0.7)
cols_to_drop_1
# Out:
# ['Sensor-158', 'Sensor-159', 'Sensor-293', 'Sensor-294']

# %%
# Drop columns with 0 std. dev.
cols_to_drop_2 = get_cols_with_zero_std_dev(wafers_train)
cols_to_drop_2
# Out:
# ['Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
#  'Sensor-329',
#  'Sensor-330',
#  'Sensor-331',
#  'Sensor-343',
# ...

# %%
cols_to_drop = cols_to_drop_1 + cols_to_drop_2
cols_to_drop
# Out:
# ['Sensor-158',
#  'Sensor-159',
#  'Sensor-293',
#  'Sensor-294',
#  'Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
# ...

# %%
# Separate Features and Labels Out
X,y = wafers_train.drop(cols_to_drop,axis=1),wafers_train[['Good/Bad']]

# %%
X.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  \
# 55  Wafer-856       NaN   2532.45  2191.1333  2197.6570    1.1569   89.7222
# 88  Wafer-889   3221.21   2391.20  2189.9667  1046.6212    0.8662  102.3622
# 26  Wafer-827   2951.85   2525.00  2189.5777  1320.3197    1.3459  100.7744
# 42  Wafer-843   2982.07   2447.06  2199.6334  1242.8420    1.4083   99.2178
# 69  Wafer-870   3058.08   2524.60  2192.3778  1110.5453    0.8147   99.2922
#
#     Sensor-8  Sensor-9  Sensor-10  ...  Sensor-582  Sensor-583  Sensor-584  \
# 55    0.1251    1.5762     0.0028  ...         NaN      0.4936      0.0113
# 88    0.1208    1.4756    -0.0025  ...         NaN      0.4940      0.0123
# 26    0.1234    1.5590    -0.0032  ...     53.8577      0.5025      0.0178
# 42    0.1221    1.4542     0.0142  ...         NaN      0.4993      0.0151
# 69    0.1226    1.4958     0.0004  ...     24.6547      0.4974      0.0171
#
# ...

# %%
y.head()
# Out:
#     Good/Bad
# 55        -1
# 88        -1
# 26        -1
# 42        -1
# 69        -1

# %%
y.shape
# Out:
# (80, 1)

# %%
# Data Transfromation
from sklearn.preprocessing import  RobustScaler
from sklearn.preprocessing import  StandardScaler
from sklearn.pipeline import  Pipeline
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

imputer = KNNImputer(n_neighbors=3)
preprocessing_pipeline = Pipeline(
    steps = [('imputer',imputer),
             ('scaler',RobustScaler())]
)

preprocessing_pipeline
# Out:
# Pipeline(steps=[('imputer', KNNImputer(n_neighbors=3)),
#                 ('scaler', RobustScaler())])

# %%
X_trans = preprocessing_pipeline.fit_transform(X)

# %%
X = X.drop('Unnamed: 0',axis=1)

# %%
X_trans
# Out:
# array([[-0.02781221,  0.37395233, -0.4289214 , ...,  0.        ,
#          0.75955556,  0.        ],
#        [ 2.50431022, -1.38644649, -0.47986463, ..., -0.51612903,
#         -0.52610857,  0.        ],
#        [-0.60204699,  0.28110298, -0.49685153, ...,  0.58064516,
#         -0.08775867,  0.        ],
#        ...,
#        [-0.03223295,  0.21779093,  1.03590393, ...,  0.12903226,
#         -0.17805529,  0.        ],
#        [ 0.03396281,  0.87459106,  0.53517467, ...,  0.29032258,
#          0.28421459,  0.        ],
#        [ 0.86164048,  0.3813055 , -0.59146288, ..., -0.16129032,
#         -0.20782888,  0.        ]])
